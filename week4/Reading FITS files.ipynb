# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import galsim
#import pyfits
#import astropy.io.fits
from astropy.io import fits

# %%
hdu_list = fits.open("output/demo1.fits")

# %%
hdu_list.info()
# Out:
# Filename: output/demo1.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      20   (134, 134)   float32

# %%
hdu_list.close()

# %%
image_data = fits.getdata("output/demo1.fits")

# %%
imshow(image_data, cmap="gray")
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x4b53758>

# %%
image_demo2 = fits.getdata("output/demo2.fits")

# %%
imshow(image_demo2, cmap="gray"); colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x4f1d878>

# %%
image_demo3 = fits.getdata("output/demo3.fits")
imshow(image_demo3, cmap="gray"); colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x5232f38>
